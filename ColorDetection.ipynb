# %%
# Load the Drive helper and mount
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import argparse
ap = argparse.ArgumentParser()
ap.add_argument('-i', '--image', required=True, help="Image Path")
args = vars(ap.parse_args())
img_path = args['/content/drive/1.PNG']
#Reading image with opencv
img = cv2.imread(img_path)
# Out:
# usage: ipykernel_launcher.py [-h] -i IMAGE
# ipykernel_launcher.py: error: the following arguments are required: -i/--image
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2890: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
# !ls drive/1.PNG
# Out:
# drive/1.PNG

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd

img = cv2.imread('drive/1.PNG',0)

plt.imshow(img)
plt.show()

# %%
import argparse
ap = argparse.ArgumentParser()
ap.add_argument('-i', '--image', required=True, help="Image Path")
args = vars(ap.parse_args())
img_path = args['image']
#Reading image with opencv
img = cv2.imread(img_path)

# %%
# !ls
# Out:
# adc.json  drive  sample_data

# %%
#Reading csv file with pandas and giving names to each column
index=["color","color_name","hex","R","G","B"]
csv = pd.read_csv('/content/drive/colors (05185364).csv', names=index, header=None)

# %%
cv2.namedWindow('/content/drive/1.PNG')
cv2.setMouseCallback('/content/drive/1.PNG',draw_function)

# %%
import cv2
import numpy as np
import pandas as pd
import argparse

#Creating argument parser to take image path from command line
# ap = argparse.ArgumentParser()
# ap.add_argument('-i', '--/content/drive/MyDrive/IMG_0932.JPG', required=True, help="Image Path")
# args = vars(ap.parse_args())
# img_path = args['/content/drive/MyDrive/IMG_0932.JPG']

#Reading the image with opencv
img = cv2.imread('/content/drive/MyDrive/IMG_0932.JPG')

#declaring global variables (are used later on)
clicked = False
r = g = b = xpos = ypos = 0

#Reading csv file with pandas and giving names to each column
index=["color","color_name","hex","R","G","B"]
csv = pd.read_csv('/content/drive/MyDrive/colors.csv', names=index, header=None)

#function to calculate minimum distance from all colors and get the most matching color
def getColorName(R,G,B):
    minimum = 10000
    for i in range(len(csv)):
        d = abs(R- int(csv.loc[i,"R"])) + abs(G- int(csv.loc[i,"G"]))+ abs(B- int(csv.loc[i,"B"]))
        if(d<=minimum):
            minimum = d
            cname = csv.loc[i,"color_name"]
    return cname

#function to get x,y coordinates of mouse double click
def draw_function(event, x,y,flags,param):
    if event == cv2.EVENT_LBUTTONDBLCLK:
        global b,g,r,xpos,ypos, clicked
        clicked = True
        xpos = x
        ypos = y
        b,g,r = img[y,x]
        b = int(b)
        g = int(g)
        r = int(r)
       
cv2.namedWindow('image')
cv2.setMouseCallback('image',draw_function)

while(1):

    cv2.imshow("image",img)
    if (clicked):
   
        #cv2.rectangle(image, startpoint, endpoint, color, thickness)-1 fills entire rectangle 
        cv2.rectangle(img,(20,20), (750,60), (b,g,r), -1)

        #Creating text string to display( Color name and RGB values )
        text = getColorName(r,g,b) + ' R='+ str(r) +  ' G='+ str(g) +  ' B='+ str(b)
        
        #cv2.putText(img,text,start,font(0-7),fontScale,color,thickness,lineType )
        cv2.putText(img, text,(50,50),2,0.8,(255,255,255),2,cv2.LINE_AA)

        #For very light colours we will display text in black colour
        if(r+g+b>=600):
            cv2.putText(img, text,(50,50),2,0.8,(0,0,0),2,cv2.LINE_AA)
            
        clicked=False

    #Break the loop when user hits 'esc' key    
    if cv2.waitKey(20) & 0xFF ==27:
        break
    
cv2.destroyAllWindows()

# %%
import pandas as pd
index=["color","color_name","hex","R","G","B"]
csv = pd.read_csv('/content/drive/MyDrive/colors.csv', names=index, header=None)

# %%
import cv2
img = cv2.imread('/content/drive/MyDrive/colorpic.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
img.shape
# Out:
# (662, 1000, 3)

# %%
r = g = b = xpos = ypos = 246

# %%
def getColorName(R,G,B):
    minimum = 10000
    for i in range(len(csv)):
        d = abs(R- int(csv.loc[i,"R"])) + abs(G- int(csv.loc[i,"G"]))+ abs(B- int(csv.loc[i,"B"]))
        if(d<=minimum):
            minimum = d
            cname = csv.loc[i,"color_name"]
    return cname

# %%
def draw_function(event, x,y,flags,param):
    
        global b,g,r,xpos,ypos
        
        xpos = x
        ypos = y
        b,g,r = img[y,x]
        b = int(b)
        g = int(g)
        r = int(r)

# %%
 plt.imshow(img)

   
#cv2.rectangle(image, startpoint, endpoint, color, thickness)-1 fills entire rectangle 
#cv2.rectangle(img,(128,128), (750,60), (b,g,r), -1)

#Creating text string to display( Color name and RGB values )
text = getColorName(r,g,b) + ' R='+ str(r) +  ' G='+ str(g) +  ' B='+ str(b)

# #cv2.putText(img,text,start,font(0-7),fontScale,color,thickness,lineType )
# cv2.putText(img, text,(50,50),2,0.8,(255,255,255),2,cv2.LINE_AA)

# #For very light colours we will display text in black colour
# if(r+g+b>=600):
#     cv2.putText(img, text,(50,50),2,0.8,(0,0,0),2,cv2.LINE_AA)

# %%
text
# Out:
# 'Dark Gray R=164.0 G=161.0 B=166.0'

# %%
img[390:410, 290:310]

# %%
img.shape
# Out:
# (591, 465, 3)

# %%
img[int((height-roi_size)/2):int((height+roi_size)/2),int((width-roi_size)/2):int((width+roi_size)/2)].shape
# Out:
# (20, 20, 3)

# %%
img[int(height/2):int(height/2),int(width/2):int(width/2)]
# Out:
# array([], shape=(0, 0, 3), dtype=uint8)

# %%
print(int(height/2))
print(int(width/2))
print(int(width/2))
# Out:
# 295
# 232

# %%
roi_values.shape
# Out:
# (100, 100, 3)

# %%
img[int((height-roi_size)/2):int(((height+roi_size)/2)),int((width-roi_size)/2):int(((width+roi_size)/2))]

# %%
img[int((height/2)-roi_size):int((height/2)+roi_size),int((width/2)-roi_size):int((width/2)+roi_size)]

# %%
import cv2
import numpy as np
from scipy import stats
import pandas as pd
import matplotlib.pyplot as plt

img = cv2.imread('/content/drive/MyDrive/14.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
height, width = img.shape[:2]
# Change these values to fit the size of your region of interest
roi_size = 10 # (10x10)
roi_values = img[int((height-roi_size)/2):int((height+roi_size)/2),int((width-roi_size)/2):int((width+roi_size)/2)]
r = stats.mode(roi_values[:,:,0].flatten())[0][0]
g = stats.mode(roi_values[:,:,1].flatten())[0][0]
b = stats.mode(roi_values[:,:,2].flatten())[0][0]

# r = stats.mode(roi_values[0].flatten())[0][0]
# g = stats.mode(roi_values[1].flatten())[0][0]
# b = stats.mode(roi_values[2].flatten())[0][0]


#img = cv2.circle(img, (int(((height-roi_size)/3)+int((height+roi_size)/3)/2),int(((width-roi_size)/3)+int((width+roi_size)/3)/2)), radius=20, color=(0, 0, 255), thickness=-1)



print("R: {}  G: {}  B: {}".format(str((r)), str((g)), str((b))))


index=["color","color_name","hex","R","G","B"]
csv = pd.read_csv('/content/drive/MyDrive/colors.csv', names=index, header=None)

def getColorName(R,G,B):
    minimum = 10000
    for i in range(len(csv)):
        d = abs(R- int(csv.loc[i,"R"])) + abs(G- int(csv.loc[i,"G"]))+ abs(B- int(csv.loc[i,"B"]))
        if(d<=minimum):
            minimum = d
            cname = csv.loc[i,"color_name"]
    return cname

text = getColorName(r,g,b) + ' R='+ str(r) +  ' G='+ str(g) +  ' B='+ str(b)
print(text)
plt.imshow(img)
# Out:
# R: 227  G: 196  B: 6
# Citrine R=227 G=196 B=6

# %%
def get_pixel_value(pixel):
    return int(pixel[0] + 256*pixel[1] + 256*256*pixel[2])

# %%
get_pixel_value(roi_values[0,0])
# Out:
# 13159124

# %%
def get_rgb_values(pixel_value):
    red = pixel_value%256
    pixel_value //= 256
    green = pixel_value%256
    pixel_value //= 256
    blue = pixel_value
    return [red,green,blue]

# %%
def find_most_common_pixel(image):
    histogram = {}  #Dictionary keeps count of different kinds of pixels in image

    for x in range(10):
        for y in range(10):
            pixel_val = get_pixel_value(image[x,y])

            if pixel_val in histogram:
                histogram[pixel_val] += 1 #Increment count
            else:
                histogram[pixel_val] = 1 #pixel_val encountered for the first time

    mode_pixel_val = max(histogram, key = histogram.get) #Find pixel_val whose count is maximum
    return get_rgb_values(mode_pixel_val)  #Returna a list containing RGB Value of the median pixel

# %%
find_most_common_pixel(roi_values)
# Out:
# [208, 200, 197]

# %%
img[0,0,:]
# Out:
# array([255, 255, 255], dtype=uint8)

# %%
roi_values

# %%
roi_values

# %%
import cv2
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread('/content/drive/MyDrive/5.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
csv
# Out:
#                     color             color_name      hex    R    G    B
# 0      air_force_blue_raf   Air Force Blue (Raf)  #5d8aa8   93  138  168
# 1     air_force_blue_usaf  Air Force Blue (Usaf)  #00308f    0   48  143
# 2    air_superiority_blue   Air Superiority Blue  #72a0c1  114  160  193
# 3         alabama_crimson        Alabama Crimson  #a32638  163   38   56
# 4              alice_blue             Alice Blue  #f0f8ff  240  248  255
# ..                    ...                    ...      ...  ...  ...  ...
# 860         yellow_orange          Yellow Orange  #ffae42  255  174   66
# 861        yellow_process       Yellow (Process)  #ffef00  255  239    0
# 862            yellow_ryb           Yellow (Ryb)  #fefe33  254  254   51
# 863                zaffre                 Zaffre  #0014a8    0   20  168
# 864     zinnwaldite_brown      Zinnwaldite Brown  #2c1608   44   22    8
#
# [865 rows x 6 columns]

# %%
int(((height-roi_size)/2)+int((height+roi_size)/2)/2),int((width-roi_size)/2)+int((width+roi_size)/2)/2)
# Out:
#   File "<ipython-input-126-25c12f7d3d84>", line 1
#     int(((height-roi_size)/2)+int((height+roi_size)/2)/2),int((width-roi_size)/2)+int((width+roi_size)/2)/2)
#                                                                                                            ^
# SyntaxError: invalid syntax

# %%
int(((height-roi_size)/2)+int((height+roi_size)/2)/2),int(((width-roi_size)/2)+int((width+roi_size)/2)/2)
# Out:
# 438

# %%
int(((width-roi_size)/2)+int((width+roi_size)/2)/2)
# Out:
# 343

# %%
img.shape
# Out:
# (1500, 1125, 3)

# %%
roi_values.shape
# Out:
# (20, 20, 3)

# %%
import cv2
import numpy as np
from scipy import stats
import pandas as pd
import matplotlib.pyplot as plt

img = cv2.imread('/content/drive/MyDrive/a.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
height, width = img.shape[:2]

roi_size = 20 
roi_values = img[int((height-roi_size)/2):int((height+roi_size)/2),int((width-roi_size)/2):int((width+roi_size)/2)]


def get_pixel_value(pixel):
    return int(pixel[0] + 256*pixel[1] + 256*256*pixel[2])

def get_rgb_values(pixel_value):
    red = pixel_value%256
    pixel_value //= 256
    green = pixel_value%256
    pixel_value //= 256
    blue = pixel_value
    return [red,green,blue]

def find_most_common_pixel(image):
    histogram = {}  #Dictionary keeps count of different kinds of pixels in image

    for x in range(image.shape[0]):
        for y in range(image.shape[1]):
            pixel_val = get_pixel_value(image[x,y])

            if pixel_val in histogram:
                histogram[pixel_val] += 1 #Increment count
            else:
                histogram[pixel_val] = 1 #pixel_val encountered for the first time

    mode_pixel_val = max(histogram, key = histogram.get) #Find pixel_val whose count is maximum
    return get_rgb_values(mode_pixel_val)  #Returna a list containing RGB Value of the median pixel

r = find_most_common_pixel(roi_values)[0]
g = find_most_common_pixel(roi_values)[1]
b = find_most_common_pixel(roi_values)[2]



#img = cv2.circle(img, (int((int((height-roi_size)/2) + int((height+roi_size)/2))/2),int((int((width-roi_size)/2) + int((width+roi_size)/2))/2)) , radius=10, color=(0, 0, 255), thickness=-1)
img = cv2.rectangle(img, (int((height-roi_size)/2), int((height+roi_size)/2)),(int((width-roi_size)/2),int((width+roi_size)/2)) , color=(0, 0, 255), thickness=10)


print("R: {}  G: {}  B: {}".format(str((r)), str((g)), str((b))))


index=["color","color_name","hex","R","G","B"]
csv = pd.read_csv('/content/drive/MyDrive/colors.csv', names=index, header=None)

def getColorName(R,G,B):
    minimum = 10000
    for i in range(len(csv)):
        d = abs(R- int(csv.loc[i,"R"])) + abs(G- int(csv.loc[i,"G"]))+ abs(B- int(csv.loc[i,"B"]))
        if(d<=minimum):
            minimum = d
            cname = csv.loc[i,"color_name"]
    return cname

text = getColorName(r,g,b) + ' R='+ str(r) +  ' G='+ str(g) +  ' B='+ str(b)
print(text)
plt.imshow(img)
# Out:
# R: 210  G: 230  B: 179
# Tea Green R=210 G=230 B=179

# %%
import webcolors

def closest_colour(requested_colour):
    min_colours = {}
    #for key, name in webcolors.CSS3_NAMES_TO_HEX.items():
    for key, name in webcolors.CSS3_HEX_TO_NAMES.items():
        r_c, g_c, b_c = webcolors.hex_to_rgb(key)
        rd = (r_c - requested_colour[0]) ** 2
        gd = (g_c - requested_colour[1]) ** 2
        bd = (b_c - requested_colour[2]) ** 2
        min_colours[(rd + gd + bd)] = name
    return min_colours[min(min_colours.keys())]

def get_colour_name(requested_colour):
    try:
        closest_name = actual_name = webcolors.rgb_to_name(requested_colour)
    except ValueError:
        closest_name = closest_colour(requested_colour)
        actual_name = None
    return actual_name, closest_name

requested_colour = (r, g, b)
actual_name, closest_name = get_colour_name(requested_colour)

print("Actual colour name:", actual_name, ", closest colour name:", closest_name)
# Out:
# Actual colour name: None , closest colour name: lavender
